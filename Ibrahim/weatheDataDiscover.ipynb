# %%
import pandas as pd
import matplotlib.pyplot as plt
df_silicon = pd.read_csv('../Data/weather_Silicon_Valley_hourly.csv')
df_pasdan = pd.read_csv('../Data/weather_Pasadena_hourly.csv')
df_silicon
# Out:
#       Stn Id    Stn Name       CIMIS Region        Date  Hour (PST)  Jul  \
# 0        171  Union City  San Francisco Bay    2/2/2018         100   33
# 1        171  Union City  San Francisco Bay    2/2/2018         200   33
# 2        171  Union City  San Francisco Bay    2/2/2018         300   33
# 3        171  Union City  San Francisco Bay    2/2/2018         400   33
# 4        171  Union City  San Francisco Bay    2/2/2018         500   33
# ...      ...         ...                ...         ...         ...  ...
# 7987     171  Union City  San Francisco Bay  12/31/2018        2000  365
# 7988     171  Union City  San Francisco Bay  12/31/2018        2100  365
# 7989     171  Union City  San Francisco Bay  12/31/2018        2200  365
# 7990     171  Union City  San Francisco Bay  12/31/2018        2300  365
# 7991     171  Union City  San Francisco Bay  12/31/2018        2400  365
#
#       ETo (mm) qc  Precip (mm) qc.1  ...  Rel Hum (%) qc.5  Dew Point (C)  \
# ...

# %%
df_silicon.describe()
# Out:
#        Stn Id   Hour (PST)          Jul     ETo (mm)  Precip (mm)  \
# count  7992.0  7992.000000  7992.000000  7848.000000  7845.000000
# mean    171.0  1250.000000   199.000000     0.133253     0.030488
# std       0.0   692.261966    96.134401     0.197667     0.249945
# min     171.0   100.000000    33.000000     0.000000     0.000000
# 25%     171.0   675.000000   116.000000     0.000000     0.000000
# 50%     171.0  1250.000000   199.000000     0.010000     0.000000
# 75%     171.0  1825.000000   282.000000     0.230000     0.000000
# max     171.0  2400.000000   365.000000     0.790000     5.840000
#
#        Sol Rad (W/sq.m)  Vap Pres (kPa)  Air Temp (C)  Rel Hum (%)  \
# count       7848.000000     7845.000000   7380.000000  7380.000000
# mean         199.823777        1.084347     13.679607    72.384959
# std          287.059797        0.368109      5.731299    16.856743
# min            0.000000        0.000000     -7.900000    12.000000
# ...

# %%
plt.style.use('ggplot')

# %%
df_pasdan.describe()
# Out:
#        Stn Id   Hour (PST)          Jul     ETo (mm)  Precip (mm)  \
# count  7992.0  7992.000000  7992.000000  7989.000000  7989.000000
# mean    159.0  1250.000000   199.000000     0.177796     0.045675
# std       0.0   692.261966    96.134401     0.241830     0.434239
# min     159.0   100.000000    33.000000     0.000000     0.000000
# 25%     159.0   675.000000   116.000000     0.000000     0.000000
# 50%     159.0  1250.000000   199.000000     0.040000     0.000000
# 75%     159.0  1825.000000   282.000000     0.310000     0.000000
# max     159.0  2400.000000   365.000000     1.000000    11.900000
#
#        Sol Rad (W/sq.m)  Vap Pres (kPa)  Air Temp (C)  Rel Hum (%)  \
# count       7989.000000     7989.000000   7959.000000  7959.000000
# mean         242.144574        1.138002     18.829074    52.803870
# std          331.867677        0.453631      6.624532    20.307305
# min            0.000000        0.100000      0.700000     3.000000
# ...

# %%
df_pasdan
# Out:
#       Stn Id  Stn Name       CIMIS Region        Date  Hour (PST)  Jul  \
# 0        159  Monrovia  Los Angeles Basin    2/2/2018         100   33
# 1        159  Monrovia  Los Angeles Basin    2/2/2018         200   33
# 2        159  Monrovia  Los Angeles Basin    2/2/2018         300   33
# 3        159  Monrovia  Los Angeles Basin    2/2/2018         400   33
# 4        159  Monrovia  Los Angeles Basin    2/2/2018         500   33
# ...      ...       ...                ...         ...         ...  ...
# 7987     159  Monrovia  Los Angeles Basin  12/31/2018        2000  365
# 7988     159  Monrovia  Los Angeles Basin  12/31/2018        2100  365
# 7989     159  Monrovia  Los Angeles Basin  12/31/2018        2200  365
# 7990     159  Monrovia  Los Angeles Basin  12/31/2018        2300  365
# 7991     159  Monrovia  Los Angeles Basin  12/31/2018        2400  365
#
#       ETo (mm) qc  Precip (mm) qc.1  ...  Rel Hum (%) qc.5  Dew Point (C)  \
# ...

# %%
print(df_silicon.columns is df_pasdan.columns)
# Out:
# False

# %%
plt.figure(figsize=(50,7))
plt.scatter(df_silicon['Date'], df_silicon['Wind Speed (m/s)'])
